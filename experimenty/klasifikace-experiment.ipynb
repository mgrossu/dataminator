# %% [markdown]
# # Klasifikace

# %% [markdown]
# ## Dataset pro tuto metodu dolování dat
# Pro dva druhy (Cammeo a Osmancik) bylo pořízeno celkem 3810 snímků rýžových zrn, které byly zpracovány a byly provedeny závěry o vlastnostech. Pro každé zrnko rýže bylo získáno 7 morfologických znaků.
#
# https://www.kaggle.com/datasets/muratkokludataset/rice-dataset-commeo-and-osmancik?resource=download

# %% [markdown]
# ## Nejdřív se načte dataset a prozkoumá se

# %%
import pandas as pd

#nacteni dat z xlsx souboru
df = pd.read_excel("datasets/Rice_Cammeo_Osmancik.xlsx")
df.head()
# Out:
#     Area   Perimeter  Major_Axis_Length  Minor_Axis_Length  Eccentricity  \
# 0  15231  525.578979         229.749878          85.093788      0.928882
# 1  14656  494.311005         206.020065          91.730972      0.895405
# 2  14634  501.122009         214.106781          87.768288      0.912118
# 3  13176  458.342987         193.337387          87.448395      0.891861
# 4  14688  507.166992         211.743378          89.312454      0.906691
#
#    Convex_Area    Extent   Class
# 0        15617  0.572896  Cammeo
# 1        15072  0.615436  Cammeo
# 2        14954  0.693259  Cammeo
# 3        13368  0.640669  Cammeo
# 4        15262  0.646024  Cammeo

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3810 entries, 0 to 3809
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Area               3810 non-null   int64
#  1   Perimeter          3810 non-null   float64
#  2   Major_Axis_Length  3810 non-null   float64
#  3   Minor_Axis_Length  3810 non-null   float64
#  4   Eccentricity       3810 non-null   float64
#  5   Convex_Area        3810 non-null   int64
#  6   Extent             3810 non-null   float64
#  7   Class              3810 non-null   object
# dtypes: float64(5), int64(2), object(1)
# memory usage: 238.2+ KB

# %%
df.nunique().sort_values()
# Out:
# Class                   2
# Area                 2828
# Convex_Area          2857
# Perimeter            3738
# Eccentricity         3803
# Minor_Axis_Length    3804
# Extent               3804
# Major_Axis_Length    3808
# dtype: int64

# %%
df.isna().sum()
# Out:
# Area                 0
# Perimeter            0
# Major_Axis_Length    0
# Minor_Axis_Length    0
# Eccentricity         0
# Convex_Area          0
# Extent               0
# Class                0
# dtype: int64

# %%
df.describe()
# Out:
#                Area    Perimeter  Major_Axis_Length  Minor_Axis_Length  \
# count   3810.000000  3810.000000        3810.000000        3810.000000
# mean   12667.727559   454.239180         188.776222          86.313750
# std     1732.367706    35.597081          17.448679           5.729817
# min     7551.000000   359.100006         145.264465          59.532406
# 25%    11370.500000   426.144753         174.353855          82.731695
# 50%    12421.500000   448.852493         185.810059          86.434647
# 75%    13950.000000   483.683746         203.550438          90.143677
# max    18913.000000   548.445984         239.010498         107.542450
#
#        Eccentricity   Convex_Area       Extent
# count   3810.000000   3810.000000  3810.000000
# mean       0.886871  12952.496850     0.661934
# std        0.020818   1776.972042     0.077239
# min        0.777233   7723.000000     0.497413
# 25%        0.872402  11626.250000     0.598862
# 50%        0.889050  12706.500000     0.645361
# 75%        0.902588  14284.000000     0.726562
# max        0.948007  19099.000000     0.861050

# %%
df[df.columns[:-1]].hist(figsize=(14,10))
# Out:
# array([[<AxesSubplot:title={'center':'Area'}>,
#         <AxesSubplot:title={'center':'Perimeter'}>,
#         <AxesSubplot:title={'center':'Major_Axis_Length'}>],
#        [<AxesSubplot:title={'center':'Minor_Axis_Length'}>,
#         <AxesSubplot:title={'center':'Eccentricity'}>,
#         <AxesSubplot:title={'center':'Convex_Area'}>],
#        [<AxesSubplot:title={'center':'Extent'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ## Použití knihovny scikit-learn

# %%
X = df[df.columns[:-1]]
y = df['Class']

# %% [markdown]
# Data rozdelime na trenovaci a testovaci mnozinu

# %%
from sklearn.model_selection import train_test_split

#rozdeleni datove sady na trenovaci a testovaci mnozinu
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=14)

# %% [markdown]
# ## Rozhodovací stromy

# %%
#nacteni funkce z knihovny
from sklearn.tree import DecisionTreeClassifier

#tvorba rozhodovaciho stromu
dt_clf = DecisionTreeClassifier()
#trenovani
dt_clf = dt_clf.fit(X_train,y_train)

# %%
#testovani
y_predicted_dt = dt_clf.predict(X_test)

# %%
from sklearn import tree
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(25,12))
_=tree.plot_tree(dt_clf, feature_names=df[df.columns[:-1]].columns, class_names=df['Class'].values, filled=True)
fig.show()

# %%
from sklearn import metrics

dt_accuracy = metrics.accuracy_score(y_test,y_predicted_dt)
dt_matrix = metrics.confusion_matrix(y_test, y_predicted_dt)

# %% [markdown]
# ## Náhodné lesy

# %%
from sklearn.ensemble import RandomForestClassifier

#tvorba nahodneho lesa
rf_clf = RandomForestClassifier()
rf_clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
#testovani
y_predicted_rf = rf_clf.predict(X_test)

rf_accuracy = metrics.accuracy_score(y_test, y_predicted_rf)
rf_matrix = metrics.confusion_matrix(y_test, y_predicted_rf)

# %% [markdown]
# ## Bayesovská klasifikace

# %%
from sklearn.naive_bayes import GaussianNB

#tvorba bayesovské klasifikace
nb_clf = GaussianNB()
nb_clf.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_predicted_nb = nb_clf.predict(X_test)

nb_accuracy = metrics.accuracy_score(y_test, y_predicted_nb)
nb_matrix = metrics.confusion_matrix(y_test, y_predicted_nb)

# %% [markdown]
# ## Neuronové sítě

# %% [markdown]
# Data pro neuronovou síť je třeba normalizovat

# %%
from sklearn.preprocessing import normalize

X_normalized = normalize(X, norm='max')

X_train_n, X_test_n, y_train_n, y_test_n = train_test_split(X_normalized,y, random_state=14)

# %%
from sklearn.neural_network import MLPClassifier

mlp_clf = MLPClassifier(hidden_layer_sizes=(4,), random_state=14)
mlp_clf.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(4,), random_state=14)

# %%
y_predicted_mlp = mlp_clf.predict(X_test)

mlp_accuracy = metrics.accuracy_score(y_test, y_predicted_mlp)
mlp_matrix = metrics.confusion_matrix(y_test, y_predicted_mlp)

# %% [markdown]
# ## K – nejbližších sousedů

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_clf = KNeighborsClassifier()
knn_clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predicted_knn = knn_clf.predict(X_test)
knn_accuracy = metrics.accuracy_score(y_test, y_predicted_knn)
knn_matrix = metrics.confusion_matrix(y_test, y_predicted_knn)

# %% [markdown]
# ## Porovnání modelu

# %%
models = pd.DataFrame({
    'Model' : ['Rozhodovací stromy', 'Náhodné lesy', 'Bayesovská klasifikace', 'Neuronové sítě', 'K–nejbližších sousedů'],
    'Skore' : [dt_accuracy*100,rf_accuracy*100,nb_accuracy*100,mlp_accuracy*100,knn_accuracy*100]
})


models.sort_values(by = 'Skore', ascending = False)
# Out:
#                      Model      Skore
# 1             Náhodné lesy  91.920252
# 2  Bayesovská klasifikace  91.605456
# 0       Rozhodovací stromy  88.457503
# 4    K–nejbližších sousedů  88.457503
# 3           Neuronové sítě  56.663169

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(17,2))
plt.subplot(1,5,1).set_title('Rozhodovací stromy')
sns.heatmap(pd.DataFrame(rf_matrix), annot=True)
plt.subplot(1,5,2).set_title('Náhodné lesy')
sns.heatmap(pd.DataFrame(dt_matrix), annot=True)
plt.subplot(1,5,3).set_title('Bayesovská klasifikace')
sns.heatmap(pd.DataFrame(nb_matrix), annot=True)
plt.subplot(1,5,4).set_title('Neuronové sítě')
sns.heatmap(pd.DataFrame(mlp_matrix), annot=True)
plt.subplot(1,5,5).set_title('K–nejbližších sousedů')
sns.heatmap(pd.DataFrame(knn_matrix), annot=True)

plt.savefig("modely.svg", format="svg")

# %% [markdown]
# ## Použití knihovny mlxtend

# %%
from mlxtend.preprocessing import minmax_scaling

# %%
#predzpracovani dat pro mlxtend a rozdeleni do trenovaci a testovaci mnoziny
df_mlxtend = df.copy()
class_map = {"Cammeo": 0, "Osmancik": 1}

df_mlxtend = df_mlxtend.applymap(lambda s: class_map.get(s) if s in class_map else s)

X_m = df_mlxtend[df_mlxtend.columns[:-1]]
y_m = df_mlxtend['Class']

X_mlxtend=minmax_scaling(X_m, columns=['Area',	'Perimeter',	'Major_Axis_Length',	'Minor_Axis_Length',	'Eccentricity',	'Convex_Area',	'Extent'])

X_trainM, X_testM, y_trainM, y_testM = train_test_split(X_mlxtend,y_m, random_state=14)
#tridy mlxtendu neprijmaji pd.Dataframe, ale np.array
X_trainM = X_trainM.values
X_testM = X_testM.values

y_trainM = y_trainM.values
y_testM = y_testM.values

# %% [markdown]
# ## Neuronové sítě

# %%
from mlxtend.classifier import Perceptron
#vytvoreni modelu a trenovani
ppn = Perceptron()
ppn.fit(X_trainM, y_trainM)

# %%
#testovani
y_predicted_ppn = ppn.predict(X_testM)

# %%
from mlxtend.evaluate import accuracy_score

accuracy_score(y_testM, y_predicted_ppn)*100
# Out:
# 85.7292759706191

# %%
from mlxtend.evaluate import confusion_matrix

cm = confusion_matrix(y_testM, y_predicted_ppn)

# %%
from mlxtend.plotting import plot_confusion_matrix

fig, ax = plot_confusion_matrix(conf_mat=cm)
plt.show()

# %%
from mlxtend.classifier import MultiLayerPerceptron as MLP

nn1 = MLP(hidden_layers=[4])

nn1 = nn1.fit(X_trainM, y_trainM)
# Out:
# /workspaces/BP/.python38/lib/python3.8/site-packages/mlxtend/classifier/multilayerperceptron.py:258: RuntimeWarning: divide by zero encountered in log
#   return - np.sum(np.log(output) * (y_target), axis=1)
# /workspaces/BP/.python38/lib/python3.8/site-packages/mlxtend/classifier/multilayerperceptron.py:258: RuntimeWarning: invalid value encountered in multiply
#   return - np.sum(np.log(output) * (y_target), axis=1)

# %%
y_predicted_nn1 = nn1.predict(X_testM)

# %%
accuracy_score(y_testM, y_predicted_nn1)*100
# Out:
# 56.66316894018888

# %%
cm2 = confusion_matrix(y_testM, y_predicted_nn1)
fig, ax = plot_confusion_matrix(conf_mat=cm2)
plt.show()

# %%
from mlxtend.classifier import Adaline

ada = Adaline()
ada.fit(X_trainM, y_trainM)

# %%
y_predicted_ada=ada.predict(X_testM)

# %%
accuracy_score(y_testM, y_predicted_ada)*100
# Out:
# 92.86463798530956

# %%
cm3 = confusion_matrix(y_testM, y_predicted_ada)
fig, ax = plot_confusion_matrix(conf_mat=cm3)
plt.show()

# %% [markdown]
# ## Použití knihovny PyCaret

# %%
from pycaret.classification import *

# %%
#predzpracovani dat, rozdeleni na testovaci a trenovaci mnozinu, nastaveni atributu podle, ktereho se bude klasifikova a interaktivni mod vypnuty
exp = setup(data=df, target='Class', silent=True)
# Out:
# <style type="text/css">
# #T_877d0_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_877d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_877d0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_877d0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_877d0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_877d0_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_877d0_row0_col1" class="data row0 col1" >2103</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_877d0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_877d0_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_877d0_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_877d0_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_877d0_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_877d0_row3_col1" class="data row3 col1" >Cammeo: 0, Osmancik: 1</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_877d0_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_877d0_row4_col1" class="data row4 col1" >(3810, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_877d0_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_877d0_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_877d0_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_877d0_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_877d0_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_877d0_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_877d0_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_877d0_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_877d0_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_877d0_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_877d0_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_877d0_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_877d0_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_877d0_row11_col1" class="data row11 col1" >(2666, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_877d0_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_877d0_row12_col1" class="data row12 col1" >(1144, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_877d0_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_877d0_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_877d0_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_877d0_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_877d0_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_877d0_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_877d0_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_877d0_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_877d0_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_877d0_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_877d0_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_877d0_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_877d0_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_877d0_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_877d0_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_877d0_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_877d0_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_877d0_row21_col1" class="data row21 col1" >5192</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_877d0_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_877d0_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_877d0_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_877d0_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_877d0_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_877d0_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_877d0_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_877d0_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_877d0_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_877d0_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_877d0_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_877d0_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_877d0_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_877d0_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_877d0_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_877d0_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_877d0_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_877d0_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_877d0_row3

# %% [markdown]
# ## Rozhodovací stromy

# %%
#vytvoreni, trenovani a testovani modelu
dt = create_model('dt', cross_validation=False)
# Out:
#    Accuracy     AUC  Recall  Prec.      F1   Kappa     MCC
# 0    0.8916  0.8892  0.9128  0.893  0.9028  0.7803  0.7806

# %%
#vykresleni rozhodovaciho stromu
plot_model(dt, plot = 'tree')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif

# %%
plot_model(dt, plot = 'confusion_matrix')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif

# %% [markdown]
# ## Náhodné lesy

# %%
#vytvoreni, trenovani a testovani modelu
rf = create_model('rf', cross_validation=False)
# Out:
#    Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0    0.9222  0.9731  0.9429  0.9182  0.9304  0.8422  0.8426

# %%
plot_model(rf, plot = 'confusion_matrix')

# %% [markdown]
# ## Bayesovská klasifikace

# %%
#vytvoreni, trenovani a testovani modelu
nb = create_model('nb', cross_validation=False)
# Out:
#    Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0    0.9135  0.9692  0.9366  0.9092  0.9227  0.8245  0.8249

# %%
plot_model(nb, plot='confusion_matrix')

# %% [markdown]
# ## Neuronové sítě

# %%
#vytvoreni, trenovani a testovani modelu
mlp = create_model('mlp', cross_validation=False)
# Out:
#    Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0    0.7229  0.9131  0.5483  0.9153  0.6858  0.4645  0.5138

# %%
plot_model(mlp, plot='confusion_matrix')

# %% [markdown]
# ## K – nejbližších sousedů

# %%
#vytvoreni, trenovani a testovani modelu
knn = create_model('knn', cross_validation=False)
# Out:
#    Accuracy     AUC  Recall   Prec.      F1   Kappa   MCC
# 0     0.896  0.9466   0.935  0.8832  0.9084  0.7883  0.79

# %%
plot_model(knn, plot='confusion_matrix')
